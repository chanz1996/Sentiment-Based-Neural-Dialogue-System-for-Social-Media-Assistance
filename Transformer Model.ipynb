# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install emoji
# !pip install transformers
# !pip install tensorflow
# !pip install keras
# !pip install gpt_2_simple
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.24.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.11.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.9.2)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.50.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow) (21.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.1.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.12)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.14.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.9.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gpt_2_simple in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: tensorflow>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (2.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (1.21.6)
# Requirement already satisfied: toposort in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (1.7)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (2022.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (2.23.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.50.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (3.3.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (2.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (21.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (0.27.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (2.9.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (3.19.6)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (3.1.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (14.0.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (4.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (57.4.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (2.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (0.4.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.12)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.5.1->gpt_2_simple) (0.38.4)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.5.1->gpt_2_simple) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (2.14.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gpt_2_simple) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gpt_2_simple) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gpt_2_simple) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gpt_2_simple) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.5.1->gpt_2_simple) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow>=2.5.1->gpt_2_simple) (3.0.9)

# %%
import codecs
import collections
import emoji
import re
import gpt_2_simple as gpt2
from datetime import datetime
import transformers
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Getting Data

# %%
# specific format for JSON
with codecs.open('/content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/human_chat.txt', encoding='utf8') as f:
    data = f.read()
data = data.split('\n')

# %%
for row in data[:15]:
  print(row)
# Out:
# Human 1: Hi!
# Human 2: What is your favorite holiday?
# Human 1: one where I get to meet lots of different people.
# Human 2: What was the most number of people you have ever met during a holiday?
# Human 1: Hard to keep a count. Maybe 25.
# Human 2: Which holiday was that?
# Human 1: I think it was Australia
# Human 2: Do you still talk to the people you met?
# Human 1: Not really. The interactions are usually short-lived but it's fascinating to learn where people are coming from and what matters to them
# Human 2: Yea, me too. I feel like God often puts strangers in front of you, and gives you an opportunity to connect with them in that moment in deeply meaningful ways. Do you ever feel like you know things about strangers without them telling you?
# Human 1: what do you mean?
# Human 2: I think it's like a 6th sense, often seen as "cold readings" to people, but can be remarkably accurate. I once sat next to a man in a coffee and I felt a pain in my back. I asked the stranger if he had a pain. It turns out that he did in the exact spot, and said he pulled a muscle while dancing at a party. I had never met the man before and never saw him again.
# Human 1: Wow! That's interesting, borderline spooky
# Human 2: There's this practice called "Treasure Hunting" that's kind of a fun game you play in a public place. There's a book called "The Ultimate Treasure Hunt" that talks about it. You use your creativity to imagine people you will meet, and you write down a description, then you associate them with a positive message or encouraging word. Maybe you saw a teenage boy in a red hat at the shopping mall in your imagination, then while at the mall, you may find someone who matches that description. You show that you have a message for him and that you have a message for a boy in a red hat. You then give him a message of kindness or whatever was on your heart. You have no idea, sometimes you meet someone who is having a really hard day, and it brings them to tears to have a stranger show them love.
# Human 1: So, do you do treasure hunting often?

# %% [markdown]
# ## Pre-processing data

# %%
utterances = collections.defaultdict(list)

# replace emoji with text
for i in range(len(data)):

    sentence = data[i]
    data[i] = emoji.demojize(sentence)

    # removing redacted words
    data[i] = ' '.join(['' if word.startswith('<REDACTED') else word for word in data[i].split()])

    # removing extra whitespace
    data[i] = re.sub(' +', ' ', data[i])

    if sentence != data[i]:
      print('Original line: ', sentence)
      print('Transformed line: ', data[i])
      print()

    data[i] = '[' + data[i][:7] + ']' + data[i][8:]


data_to_write = '\n'.join(data)

outputfile = open("/content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/human_chat_new_processed_gpt2.txt", "wt", encoding='utf8')
n = outputfile.write(data_to_write)
outputfile.close()
# Out:
# Original line:  Human 2: Cool! very depressing plans ... stay home and work 😞 I have a project deadline very close.
# Transformed line:  Human 2: Cool! very depressing plans ... stay home and work :disappointed_face: I have a project deadline very close.
#
# Original line:  Human 1: 😐 hope you get your work done very soon! a bug free weekend!
# Transformed line:  Human 1: :neutral_face: hope you get your work done very soon! a bug free weekend!
#
# Original line:  Human 1:  Actually no idea, but it will take the entire day for that.
# Transformed line:  Human 1: Actually no idea, but it will take the entire day for that.
#
# Original line:  Human 2: yeah but I think it's good to have some rainy days in bay area, it's pretty dry here 😛
# Transformed line:  Human 2: yeah but I think it's good to have some rainy days in bay area, it's pretty dry here :face_with_tongue:
#
# Original line:  Human 2: I enjoy baking cookies. I am on a quest to bake the best chocolate chip cookie 🙂 What about you?
# Transformed line:  Human 2: I enjoy baking cookies. I am on a quest to bake the best chocolate chip cookie :slightly_smiling_face: What about you?
#
# Original line:  Human 1: I enjoy eating 🙂
# Transformed line:  Human 1: I enjoy eating :slightly_smiling_face:
#
# Original line:  Human 1: I think I'm getting sick with a cold 😞 So you should chill on my behalf too cause I'm out the game for all of December.
# Transformed line:  Human 1: I think I'm getting sick with a cold :disappointed_face: So you should chill on my behalf too cause I'm out the game for all of December.
#
# Original line:  Human 2: 😂
# Transformed line:  Human 2: :face_with_tears_of_joy:
#
# Original line:  Human 2: 😂
# Transformed line:  Human 2: :face_with_tears_of_joy:
#
# Original line:  Human 2: Yea. I think Loki is the most handsome 😀
# Transformed line:  Human 2: Yea. I think Loki is the most handsome :grinning_face:
#
# Original line:  Human 2: I am having all of the extended family over for a big meal. We will also go <REDACTED_TERM> as well. What will you do in the bahamas?
# Transformed line:  Human 2: I am having all of the extended family over for a big meal. We will also go as well. What will you do in the bahamas?
#
# Original line:  Human 1: any other hobbies besides air frying everything? 🙂
# Transformed line:  Human 1: any other hobbies besides air frying everything? :slightly_smiling_face:
#
# Original line:  Human 1: uh oh, I'd better not to plan for BBQ then instead just enjoying playing board games inside 🙂
# Transformed line:  Human 1: uh oh, I'd better not to plan for BBQ then instead just enjoying playing board games inside :slightly_smiling_face:
#
# Original line:  Human 2: hello, who am I having the pleasure to chat with 🙂
# Transformed line:  Human 2: hello, who am I having the pleasure to chat with :slightly_smiling_face:
#
# Original line:  Human 1: yea, a little bit, but it's okay 🙂 what do you enjoy doing outside work?
# Transformed line:  Human 1: yea, a little bit, but it's okay :slightly_smiling_face: what do you enjoy doing outside work?
#
# Original line:  Human 2: Not really. But it was fun to watch with friends 🙂 It was touching at the end of the movie
# Transformed line:  Human 2: Not really. But it was fun to watch with friends :slightly_smiling_face: It was touching at the end of the movie
#
# Original line:  Human 2: Are you sure you want the spoiler 🙂
# Transformed line:  Human 2: Are you sure you want the spoiler :slightly_smiling_face:
#
# Original line:  Human 2: 😂 well someone died at the end Or some robots, to be more accurate 😉
# Transformed line:  Human 2: :face_with_tears_of_joy: well someone died at the end Or some robots, to be more accurate :winking_face:
#
# Original line:  Human 1: then I want to watch it! you didn't spoil much 🙂
# Transformed line:  Human 1: then I want to watch it! you didn't spoil much :slightly_smiling_face:
#
# Original line:  Human 2: thanksgiving holidays 🙂
# Transformed line:  Human 2: thanksgiving holidays :slightly_smiling_face:
#
# Original line:  Human 2: Hi there 🙂 How's your day so far?
# Transformed line:  Human 2: Hi there :slightly_smiling_face: How's your day so far?
#
# Original line:  Human 1: same here. what do you love to do beside meetings? 🙂
# Transformed line:  Human 1: same here. what do you love to do beside meetings? :slightly_smiling_face:
#
# Original line:  Human 1: ah I enjoy playing soccer and tennis 🙂 unfortunately, winter is not the best time for those 🙂
# Transformed line:  Human 1: ah I enjoy playing soccer and tennis :slightly_smiling_face: unfortunately, winter is not the best time for those :slightly_smiling_face:
#
# Original line:  Human 1: yea. I enjoy playing outside though, just a little cold 🙂 what else do you do beside Yoga?
# Transformed line:  Human 1: yea. I enjoy playing outside though, just a little cold :slightly_smiling_face: what else do you do beside Yoga?
#
# Original line:  Human 1: yea definitely! I love singing Karaoke. my wife is a pianist 🙂
# Transformed line:  Human 1: yea definitely! I love singing Karaoke. my wife is a pianist :slightly_smiling_face:
#
# Original line:  Human 1: no. only eat them 😀
# Transformed line:  Human 1: no. only eat them :grinning_face:
#
# Original line:  Human 2: Hey, how are you 🙂
# Transformed line:  Human 2: Hey, how are you :slightly_smiling_face:
#
# Original line:  Human 2: Anything in general. You're so cool, I want to know more about you 🙂
# Transformed line:  Human 2: Anything in general. You're so cool, I want to know more about you :slightly_smiling_face:
#
# Original line:  Human 1: Corgi belly flop COMPILATION - cute funny dogs Corgi Flop <REDACTED_LINK>
# Transformed line:  Human 1: Corgi belly flop COMPILATION - cute funny dogs Corgi Flop
#
# Original line:  Human 2: Eggs are an excellent source of protein and hash browns certainly are yummy! 🙂
# Transformed line:  Human 2: Eggs are an excellent source of protein and hash browns certainly are yummy! :slightly_smiling_face:
#
# Original line:  Human 2: Hello! How are you doing 🙂
# Transformed line:  Human 2: Hello! How are you doing :slightly_smiling_face:
#
# Original line:  Human 2: Yup! I work in a technical role so I like to take arts and crafts-type classes now and then 🙂 Pottery sounds like a lot of fun
# Transformed line:  Human 2: Yup! I work in a technical role so I like to take arts and crafts-type classes now and then :slightly_smiling_face: Pottery sounds like a lot of fun
#
# Original line:  Human 2: Hmm I'm not sure, I just get them from a Chinese supermarket haha You seem really knowledgeable about the different kinds of teas 🙂 What made you develop this interest?
# Transformed line:  Human 2: Hmm I'm not sure, I just get them from a Chinese supermarket haha You seem really knowledgeable about the different kinds of teas :slightly_smiling_face: What made you develop this interest?
#
# Original line:  Human 1: I actually found a youtube channel called <REDACTED_TERM> that I like a lot. You should check it out! The host talks about all kinds of different teas.
# Transformed line:  Human 1: I actually found a youtube channel called that I like a lot. You should check it out! The host talks about all kinds of different teas.
#
# Original line:  Human 2: I am indeed a robot. You are absolutely right. Do you want me to read a poet like my mate <REDACTED_TERM> does?
# Transformed line:  Human 2: I am indeed a robot. You are absolutely right. Do you want me to read a poet like my mate does?
#
# Original line:  Human 1: What's your favorite computer language then 🙂
# Transformed line:  Human 1: What's your favorite computer language then :slightly_smiling_face:
#
# Original line:  Human 1:  Great! Good time to be back. We are still in planning phase and haven't fully aligned on the projects to tackle for next quarter.reat! Good time to be back. We are still in planning phase and haven't fully aligned on the projects to tackle for next quarter.
# Transformed line:  Human 1: Great! Good time to be back. We are still in planning phase and haven't fully aligned on the projects to tackle for next quarter.reat! Good time to be back. We are still in planning phase and haven't fully aligned on the projects to tackle for next quarter.
#
# Original line:  Human 1: Hehe, yeah! It seems like the quarter is being pushed earlier than from where it starts 🙂 I like these planning sessions. It makes me feel more confident about the work I am doing.
# Transformed line:  Human 1: Hehe, yeah! It seems like the quarter is being pushed earlier than from where it starts :slightly_smiling_face: I like these planning sessions. It makes me feel more confident about the work I am doing.
#
# Original line:  Human 1: Let's try something different. What about <REDACTED_TERM>? Do you always prefer lunch sync over regular meeting syncs?
# Transformed line:  Human 1: Let's try something different. What about Do you always prefer lunch sync over regular meeting syncs?
#
# Original line:  Human 2: Yeah I'm afraid I wouldn't. I feel very guilty every time I gulp down an ice cream. But hey, these days there are many types of guilt-free sweet food. For example, there's this ice cream brand called <REDACTED_TERM>. It's only 320 calories a pint. And yes, it preserves most of the normal sweet flavors.
# Transformed line:  Human 2: Yeah I'm afraid I wouldn't. I feel very guilty every time I gulp down an ice cream. But hey, these days there are many types of guilt-free sweet food. For example, there's this ice cream brand called It's only 320 calories a pint. And yes, it preserves most of the normal sweet flavors.
#
# Original line:  Human 1: Wow! The last time I paid attention to that sort of stuff was when <REDACTED_TERM> was being marketed as a fat substitute, and caused all sorts of crazy stomach upsets.
# Transformed line:  Human 1: Wow! The last time I paid attention to that sort of stuff was when was being marketed as a fat substitute, and caused all sorts of crazy stomach upsets.
#
# Original line:  Human 2: Interesting. I heard about the sweet substitute in a program called the Keto diet. Basically, we try to limit our sugar intake every day. Successful Keto dieters have recommended the <REDACTED_TERM> ice cream to fill their insatiable crave for sugar.
# Transformed line:  Human 2: Interesting. I heard about the sweet substitute in a program called the Keto diet. Basically, we try to limit our sugar intake every day. Successful Keto dieters have recommended the ice cream to fill their insatiable crave for sugar.
#
# Original line:  Human 1: Ah, maybe that's the solution I need to enjoy sweets and not feel guilty 🙂
# Transformed line:  Human 1: Ah, maybe that's the solution I need to enjoy sweets and not feel guilty :slightly_smiling_face:
#
# Original line:  Human 1: Sounds great! you need not wait for thanksgiving for pumpkin pie 🙂
# Transformed line:  Human 1: Sounds great! you need not wait for thanksgiving for pumpkin pie :slightly_smiling_face:
#
# Original line:  Human 2: My family eats healthier than I do, so it's all mine 😛 do you like stuffing? I feel like that's only available once a year
# Transformed line:  Human 2: My family eats healthier than I do, so it's all mine :face_with_tongue: do you like stuffing? I feel like that's only available once a year
#
# Original line:  Human 2: What's the best holiday deal you've found in the past?
# Transformed line:  Human 2: What's the best holiday deal you've found in the past?
#
# Original line:  Human 1: I bought the best suit ever for a price that may scare you 🙂
# Transformed line:  Human 1: I bought the best suit ever for a price that may scare you :slightly_smiling_face:
#
# Original line:  Human 2: hit me with it!
# Transformed line:  Human 2: hit me with it!
#
# Original line:  Human 2: I just got a matcha latte 🙂 Doing some work at my desk. Do you play soccer often? I'm trying to get into doing a regular physical activity
# Transformed line:  Human 2: I just got a matcha latte :slightly_smiling_face: Doing some work at my desk. Do you play soccer often? I'm trying to get into doing a regular physical activity
#
# Original line:  Human 2: Oh cool! I read a lot for fun too 🙂 My favorite genre is sci-fi fantasy.
# Transformed line:  Human 2: Oh cool! I read a lot for fun too :slightly_smiling_face: My favorite genre is sci-fi fantasy.
#
# Original line:  Human 2: are there even any negatives? what are they?
# Transformed line:  Human 2: are there even any negatives? what are they?
#
# Original line:  Human 1: I think it can take many different forms as a product. The research implication is also huge! It will signify how AI research has progressed so far and better place to tackle more futuristic problems 🙂 Sort of like stepping on the moon 🙂 I might be overselling it here 😛
# Transformed line:  Human 1: I think it can take many different forms as a product. The research implication is also huge! It will signify how AI research has progressed so far and better place to tackle more futuristic problems :slightly_smiling_face: Sort of like stepping on the moon :slightly_smiling_face: I might be overselling it here :face_with_tongue:
#
# Original line:  Human 1: The current auto-suggestions already do pretty good 🙂
# Transformed line:  Human 1: The current auto-suggestions already do pretty good :slightly_smiling_face:
#
# Original line:  Human 1: haha, pretty far fetched 🙂 Nice having this conversation with you!
# Transformed line:  Human 1: haha, pretty far fetched :slightly_smiling_face: Nice having this conversation with you!
#
# Original line:  Human 2: Same with you!
# Transformed line:  Human 2: Same with you!
#
# Original line:  Human 2: Hi 🙂
# Transformed line:  Human 2: Hi :slightly_smiling_face:
#
# Original line:  Human 2: it's so stressful 🙂
# Transformed line:  Human 2: it's so stressful :slightly_smiling_face:
#
# Original line:  Human 1: I have just seen 1 season of Friends I should give it another try though 🙂 Have you seen Frasier?
# Transformed line:  Human 1: I have just seen 1 season of Friends I should give it another try though :slightly_smiling_face: Have you seen Frasier?
#
# Original line:  Human 1: A psychiatrist working for radio .. Great humour! its actually a spinoff from a very famous series called cheers. So people are already familiar with his character.
# Transformed line:  Human 1: A psychiatrist working for radio .. Great humour! its actually a spinoff from a very famous series called cheers. So people are already familiar with his character.
#
# Original line:  Human 1: Everything is ok, had a really nice trip. Visited SF, Grand canyon and Vegas. Was a lot of fun exploring all these new places. Have you been to Grand canyon ?
# Transformed line:  Human 1: Everything is ok, had a really nice trip. Visited SF, Grand canyon and Vegas. Was a lot of fun exploring all these new places. Have you been to Grand canyon ?
#
# Original line:  Human 2: Actually not yet! May be something i can visit this christmas 🙂
# Transformed line:  Human 2: Actually not yet! May be something i can visit this christmas :slightly_smiling_face:
#
# Original line:  Human 2: Thanks for sharing your experience! Now I am thinking maybe I should join as a mentor as well since I enjoyed it as a mentee 🙂
# Transformed line:  Human 2: Thanks for sharing your experience! Now I am thinking maybe I should join as a mentor as well since I enjoyed it as a mentee :slightly_smiling_face:
#
# Original line:  Human 2: Hmm, maybe about work life balance 😉
# Transformed line:  Human 2: Hmm, maybe about work life balance :winking_face:
#
# Original line:  Human 1: Going good. In the last session, everyone had to actually prepare and give a presentation. Pretty serious stuff 😉
# Transformed line:  Human 1: Going good. In the last session, everyone had to actually prepare and give a presentation. Pretty serious stuff :winking_face:
#
# Original line:  Human 2: That's a tough scenario to be in 🙂 I firmly believe in talking this through with your partner. Though i don't know the specifics of why things went bad between your partner and his friend, but I believe things can always improve between friends.
# Transformed line:  Human 2: That's a tough scenario to be in :slightly_smiling_face: I firmly believe in talking this through with your partner. Though i don't know the specifics of why things went bad between your partner and his friend, but I believe things can always improve between friends.
#
# Original line:  Human 2: Right, I guess that's because there is no one answer to this. It depends on what you value more and some factors around you. Also, life won't be interesting if others are figuring things out for you 😉
# Transformed line:  Human 2: Right, I guess that's because there is no one answer to this. It depends on what you value more and some factors around you. Also, life won't be interesting if others are figuring things out for you :winking_face:
#
# Original line:  Human 2: Hehe, everyone is much finer being single 🙂
# Transformed line:  Human 2: Hehe, everyone is much finer being single :slightly_smiling_face:
#
# Original line:  Human 2: nice! Garbanzo fritters and mussels 🙂
# Transformed line:  Human 2: nice! Garbanzo fritters and mussels :slightly_smiling_face:
#
# Original line:  Human 2: Yeah, gonna watch <REDACTED_TERM> with my friends. First time. So excited.
# Transformed line:  Human 2: Yeah, gonna watch with my friends. First time. So excited.
#
# Original line:  Human 2: lol I will try if I can watch ufc live 😉 Wow, when did you start jiu jitsu?
# Transformed line:  Human 2: lol I will try if I can watch ufc live :winking_face: Wow, when did you start jiu jitsu?
#
# Original line:  Human 1: Hope you are having fun doing that 🙂 Any plans for the weekend?
# Transformed line:  Human 1: Hope you are having fun doing that :slightly_smiling_face: Any plans for the weekend?
#
# Original line:  Human 1:  Sounds great! I recommend spain. It's perfect for road trips.
# Transformed line:  Human 1: Sounds great! I recommend spain. It's perfect for road trips.
#
# Original line:  Human 1:  Yep, i tried learning spanish too, but couldn't make much progress. But i should do decent with my german.
# Transformed line:  Human 1: Yep, i tried learning spanish too, but couldn't make much progress. But i should do decent with my german.
#
# Original line:  Human 1:  Thanks! Let me try to make all the arrangement as soon as possible. Hope you also enjoy your weekday and weekend as well
# Transformed line:  Human 1: Thanks! Let me try to make all the arrangement as soon as possible. Hope you also enjoy your weekday and weekend as well
#
# Original line:  Human 2: The last I saw him was a month ago! So yup it was great Haha, nice 🙂 Got any fun plans for the weekend?
# Transformed line:  Human 2: The last I saw him was a month ago! So yup it was great Haha, nice :slightly_smiling_face: Got any fun plans for the weekend?
#
# Original line:  Human 2: Haha 😆 Yeah I get sea sick on boats too Nothing much, just visiting some friends in San Francisco
# Transformed line:  Human 2: Haha :grinning_squinting_face: Yeah I get sea sick on boats too Nothing much, just visiting some friends in San Francisco
#
# Original line:  Human 2: nice! I love NYC 🙂 so fun to visit yeah I would probably also say New York is my favorite city inside the US I also like Paris, it's so pretty there
# Transformed line:  Human 2: nice! I love NYC :slightly_smiling_face: so fun to visit yeah I would probably also say New York is my favorite city inside the US I also like Paris, it's so pretty there
#
# Original line:  Human 1: I guess its a jacket! Very much needed that in the cold 🙂
# Transformed line:  Human 1: I guess its a jacket! Very much needed that in the cold :slightly_smiling_face:
#
# Original line:  Human 1: New york! Nice! Best place to live 🙂 .. right, except for the cold!
# Transformed line:  Human 1: New york! Nice! Best place to live :slightly_smiling_face: .. right, except for the cold!
#
# Original line:  Human 1: A couple projects that I am trying to finish up before Thanksgiving 🙂 Do you have any fun plans for the break?
# Transformed line:  Human 1: A couple projects that I am trying to finish up before Thanksgiving :slightly_smiling_face: Do you have any fun plans for the break?
#
# Original line:  Human 2: I'm exhausted by the end of it though 😛 Do you like to run long distances or mostly sprints?
# Transformed line:  Human 2: I'm exhausted by the end of it though :face_with_tongue: Do you like to run long distances or mostly sprints?
#
# Original line:  Human 2: lots of fun stuff. eating sleeping 🙂
# Transformed line:  Human 2: lots of fun stuff. eating sleeping :slightly_smiling_face:
#
# Original line:  Human 1: these are important things to do in life 😉
# Transformed line:  Human 1: these are important things to do in life :winking_face:
#
# Original line:  Human 2: yeah. keep minimalist life style only do things you have to do 🙂
# Transformed line:  Human 2: yeah. keep minimalist life style only do things you have to do :slightly_smiling_face:
#
# Original line:  Human 1: like Szechuan or Hunan? 🙂
# Transformed line:  Human 1: like Szechuan or Hunan? :slightly_smiling_face:
#
# Original line:  Human 1: I love <REDACTED_TERM> in San Mateo
# Transformed line:  Human 1: I love in San Mateo
#
# Original line:  Human 1: arghhh hard question ... I only know Ramen places for Japanese food 🙂
# Transformed line:  Human 1: arghhh hard question ... I only know Ramen places for Japanese food :slightly_smiling_face:
#
# Original line:  Human 1: San Mateo to me has the best Ramen restaurants: Parlor and Dojo? oh no question mark 🙂
# Transformed line:  Human 1: San Mateo to me has the best Ramen restaurants: Parlor and Dojo? oh no question mark :slightly_smiling_face:
#
# Original line:  Human 1: my pleasure 🙂 do you live near San Mateo?
# Transformed line:  Human 1: my pleasure :slightly_smiling_face: do you live near San Mateo?
#
# Original line:  Human 1: I just met someone who went diving in Australia. Apparently, you cannot fly 24 hrs after you dive, because your body accumulates too much <REDACTED_TERM> when breathing with a cylinder So, don't do that!
# Transformed line:  Human 1: I just met someone who went diving in Australia. Apparently, you cannot fly 24 hrs after you dive, because your body accumulates too much when breathing with a cylinder So, don't do that!
#
# Original line:  Human 2: I won a lot of money through the lottery 🙂
# Transformed line:  Human 2: I won a lot of money through the lottery :slightly_smiling_face:
#
# Original line:  Human 2: ah I'm waiting to finish work earlier to meet my son at home 🙂
# Transformed line:  Human 2: ah I'm waiting to finish work earlier to meet my son at home :slightly_smiling_face:
#
# Original line:  Human 2: ah he's like to ride his little bicycle around the house and asks me to follow 🙂 what are you up to today?
# Transformed line:  Human 2: ah he's like to ride his little bicycle around the house and asks me to follow :slightly_smiling_face: what are you up to today?
#
# Original line:  Human 2: haha that sounds like a good plan. who are you going with? 🙂
# Transformed line:  Human 2: haha that sounds like a good plan. who are you going with? :slightly_smiling_face:
#
# Original line:  Human 1: Sure, I can take a lead on that. What are you getting for your <REDACTED_TERM> year old this time?
# Transformed line:  Human 1: Sure, I can take a lead on that. What are you getting for your year old this time?
#
# Original line:  Human 1: I'm doing well. having many meetings today 🙂
# Transformed line:  Human 1: I'm doing well. having many meetings today :slightly_smiling_face:
#
# Original line:  Human 2: Lots of meetings as well 🙂 Do you have any fun plans for Thanksgiving?
# Transformed line:  Human 2: Lots of meetings as well :slightly_smiling_face: Do you have any fun plans for Thanksgiving?
#
# Original line:  Human 1: I love Survivor 🙂
# Transformed line:  Human 1: I love Survivor :slightly_smiling_face:
#
# Original line:  Human 2: no, i was busy catching up with a friend. I heard they played really well. Rooting for them this season 🙂 Ahh, they lost again 😞 Things aren't going to be too good until Steph gets better! Oh! I think they will find a way. The team still looks too strong to me.
# Transformed line:  Human 2: no, i was busy catching up with a friend. I heard they played really well. Rooting for them this season :slightly_smiling_face: Ahh, they lost again :disappointed_face: Things aren't going to be too good until Steph gets better! Oh! I think they will find a way. The team still looks too strong to me.
#
# Original line:  Human 2: not feeling too sure about it tbh. I've been super busy so I haven't study much 😞. I might join some of the study sessions later
# Transformed line:  Human 2: not feeling too sure about it tbh. I've been super busy so I haven't study much :disappointed_face:. I might join some of the study sessions later
#
# Original line:  Human 2: *ate 😂
# Transformed line:  Human 2: *ate :face_with_tears_of_joy:
#
# Original line:  Human 1: Nice... I always find it hard to fit the turkey in my small oven. Also, we are not big turkey fans... so we roll with Thanksgiving with chicken 😉
# Transformed line:  Human 1: Nice... I always find it hard to fit the turkey in my small oven. Also, we are not big turkey fans... so we roll with Thanksgiving with chicken :winking_face:
#
# Original line:  Human 1: Nice.... you are a rockstar! 😉
# Transformed line:  Human 1: Nice.... you are a rockstar! :winking_face:
#
# Original line:  Human 2: I just released a book on <REDACTED_TERM> to help people process the past 12 months and start the new year with a fresh outlook 🙂
# Transformed line:  Human 2: I just released a book on to help people process the past 12 months and start the new year with a fresh outlook :slightly_smiling_face:
#
# Original line:  Human 1: Great! Good idea to help people figuring out their new year resolutions 🙂 So how do i get a fresher outlook? 🙂
# Transformed line:  Human 1: Great! Good idea to help people figuring out their new year resolutions :slightly_smiling_face: So how do i get a fresher outlook? :slightly_smiling_face:
#
# Original line:  Human 2: We created a scholarship for leaders from <REDACTED_TERM> to visit an international institute at <REDACTED_TERM> for which there was no African representation. During the program, we also did a lot of coaching with the young leaders. This book captures a bit of that journey that we are all on, and also all the proceeds are going to fund next year's cohort.
# Transformed line:  Human 2: We created a scholarship for leaders from to visit an international institute at for which there was no African representation. During the program, we also did a lot of coaching with the young leaders. This book captures a bit of that journey that we are all on, and also all the proceeds are going to fund next year's cohort.
#
# Original line:  Human 1: Thats great! This is valuable help for the community. I think mental health is one of the bigger challenges facing humanity.
# Transformed line:  Human 1: Thats great! This is valuable help for the community. I think mental health is one of the bigger challenges facing humanity.
#
# Original line:  Human 1: That is actually a quote stolen from my TL when i joined my first company after graduation. I guess now after 5 yrs of work experience, I fully agree with it 🙂
# Transformed line:  Human 1: That is actually a quote stolen from my TL when i joined my first company after graduation. I guess now after 5 yrs of work experience, I fully agree with it :slightly_smiling_face:
#
# Original line:  Human 1: 1. stay happy; I think family and friends play a big role here. 2. Meaningful work life; this may mean exploring around with new stuff 3. multiple hobbies that keep you busy ... so on 🙂 What about you? is there a right answer to this? :)
# Transformed line:  Human 1: 1. stay happy; I think family and friends play a big role here. 2. Meaningful work life; this may mean exploring around with new stuff 3. multiple hobbies that keep you busy ... so on :slightly_smiling_face: What about you? is there a right answer to this? :)
#
# Original line:  Human 2:  1) The idea of what it must be like to be "on Earth as it is in Heaven" from the Lord's prayer. I feel like we were designed for a purpose, rather than random chance. A more concrete way to put it is simply show love to the greatest capacity we can. 2) Taking care of myself physically, mentally, spiritually. 3) Family 4) Work 5) Music
# Transformed line:  Human 2: 1) The idea of what it must be like to be "on Earth as it is in Heaven" from the Lord's prayer. I feel like we were designed for a purpose, rather than random chance. A more concrete way to put it is simply show love to the greatest capacity we can. 2) Taking care of myself physically, mentally, spiritually. 3) Family 4) Work 5) Music
#
# Original line:  Human 1: Nice! That's very thoughtful and spiritual 🙂 Also music earned a spot 🙂 yay!
# Transformed line:  Human 1: Nice! That's very thoughtful and spiritual :slightly_smiling_face: Also music earned a spot :slightly_smiling_face: yay!
#
# Original line:  Human 1: I am actually not much of a reader. I usually hide it by quoting john nash ~ reading books corrupts original thoughts 🙂
# Transformed line:  Human 1: I am actually not much of a reader. I usually hide it by quoting john nash ~ reading books corrupts original thoughts :slightly_smiling_face:
#
# Original line:  Human 1: Hmm, try taking some <REDACTED_TERM>! I'm going to see the Warriors vs. the Grizzlies. Ever see them play?
# Transformed line:  Human 1: Hmm, try taking some I'm going to see the Warriors vs. the Grizzlies. Ever see them play?
#
# Original line:  Human 2: lol, sounds better to me :) I'm actually at the <REDACTED_TERM> opening remarks
# Transformed line:  Human 2: lol, sounds better to me :) I'm actually at the opening remarks
#
# Original line:  Human 1: Very interesting. I learned a lot in this conversation today 🙂
# Transformed line:  Human 1: Very interesting. I learned a lot in this conversation today :slightly_smiling_face:
#
# Original line:  Human 2: it's nice I guess 🙂 lots of great food. Have you been to Sapporo or Hokkaido?
# Transformed line:  Human 2: it's nice I guess :slightly_smiling_face: lots of great food. Have you been to Sapporo or Hokkaido?
#
# Original line:  Human 2: Vietnam and Hongkong 🙂 did you go any where last weekend?
# Transformed line:  Human 2: Vietnam and Hongkong :slightly_smiling_face: did you go any where last weekend?
#
# Original line:  Human 2: can't wait to try your food. why not cook this Thanksgiving? 🙂
# Transformed line:  Human 2: can't wait to try your food. why not cook this Thanksgiving? :slightly_smiling_face:
#
# Original line:  Human 2: I visited a few places like the Stade Olympique: <REDACTED_LINK>
# Transformed line:  Human 2: I visited a few places like the Stade Olympique:
#
# Original line:  Human 1: Are you good at <REDACTED_TERM>?
# Transformed line:  Human 1: Are you good at
#
# Original line:  Human 2: yea you can first dump your brain and wait until technology advances to wake up 🙂 don't you believe?
# Transformed line:  Human 2: yea you can first dump your brain and wait until technology advances to wake up :slightly_smiling_face: don't you believe?
#
# Original line:  Human 1: Not a lot! But I preparing for a good vacation season 🙂 What is white collar about?
# Transformed line:  Human 1: Not a lot! But I preparing for a good vacation season :slightly_smiling_face: What is white collar about?
#
# Original line:  Human 2:  It's a show about a detective and con artist solving crimes together 🙂 What shows do you like
# Transformed line:  Human 2: It's a show about a detective and con artist solving crimes together :slightly_smiling_face: What shows do you like
#
# Original line:  Human 1: Hehe! sounds very interesting 🙂 I only see shows belonging to few genre's .. like easy going light comedy, or phychological thrillers 🙂 also some manga based series like one punch man! love it!
# Transformed line:  Human 1: Hehe! sounds very interesting :slightly_smiling_face: I only see shows belonging to few genre's .. like easy going light comedy, or phychological thrillers :slightly_smiling_face: also some manga based series like one punch man! love it!
#
# Original line:  Human 2:  I think the last one I watched was Promised Neverland and Kakegurui but I don't follow any right now
# Transformed line:  Human 2: I think the last one I watched was Promised Neverland and Kakegurui but I don't follow any right now
#
# Original line:  Human 1: Oh nice! I heard its latest season arrived last month. I have watched all previous seasons. Its a total mind bender 🙂
# Transformed line:  Human 1: Oh nice! I heard its latest season arrived last month. I have watched all previous seasons. Its a total mind bender :slightly_smiling_face:
#
# Original line:  Human 1: lol which cafe? let me guess. <REDACTED_TERM>?
# Transformed line:  Human 1: lol which cafe? let me guess.
#
# Original line:  Human 1: Yeah of course The fun fact is that the owner of <REDACTED_TERM> used to run <REDACTED_TERM>
# Transformed line:  Human 1: Yeah of course The fun fact is that the owner of used to run
#
# Original line:  Human 1: same former owner?? 🙂
# Transformed line:  Human 1: same former owner?? :slightly_smiling_face:
#
# Original line:  Human 1: I read lots of papers, but do poorly on books 😞 a recent book that I like is Zero to One by Peter Thiel
# Transformed line:  Human 1: I read lots of papers, but do poorly on books :disappointed_face: a recent book that I like is Zero to One by Peter Thiel
#
# Original line:  Human 2: I see; seems like an interesting read! 🙂
# Transformed line:  Human 2: I see; seems like an interesting read! :slightly_smiling_face:
#
# Original line:  Human 2: Traveling to warm places haha. When it's cold, you appreciate the warm climate more 🙂 If I am not traveling, then I prefer there to be snow on the ground so I can go skiing or tubing down the mountain. What about you?
# Transformed line:  Human 2: Traveling to warm places haha. When it's cold, you appreciate the warm climate more :slightly_smiling_face: If I am not traveling, then I prefer there to be snow on the ground so I can go skiing or tubing down the mountain. What about you?
#
# Original line:  Human 1: Something Deeply Hidden by Sean Carroll <REDACTED_LINK>
# Transformed line:  Human 1: Something Deeply Hidden by Sean Carroll
#
# Original line:  Human 2: yea I'm travelling to Vancouver this weekend. what about you? 🙂
# Transformed line:  Human 2: yea I'm travelling to Vancouver this weekend. what about you? :slightly_smiling_face:
#
# Original line:  Human 2: ah a mix of both conference and sight-seeing 🙂 anything beautiful sight-seeing places or good food I should try?
# Transformed line:  Human 2: ah a mix of both conference and sight-seeing :slightly_smiling_face: anything beautiful sight-seeing places or good food I should try?
#
# Original line:  Human 2: yea it's <REDACTED_TERM>, the largest machine learning conference. I'll check out Kingyo, do we need to make reservation in advance?
# Transformed line:  Human 2: yea it's the largest machine learning conference. I'll check out Kingyo, do we need to make reservation in advance?
#
# Original line:  Human 2: hmm not the local people but there will be tons of people at the conference 🙂
# Transformed line:  Human 2: hmm not the local people but there will be tons of people at the conference :slightly_smiling_face:
#
# Original line:  Human 1: It's called <REDACTED_TERM>, on the north coast of France.
# Transformed line:  Human 1: It's called on the north coast of France.

# %%
for row in data[:15]:
  print(row)
# Out:
# [Human 1] Hi!
# [Human 2] What is your favorite holiday?
# [Human 1] one where I get to meet lots of different people.
# [Human 2] What was the most number of people you have ever met during a holiday?
# [Human 1] Hard to keep a count. Maybe 25.
# [Human 2] Which holiday was that?
# [Human 1] I think it was Australia
# [Human 2] Do you still talk to the people you met?
# [Human 1] Not really. The interactions are usually short-lived but it's fascinating to learn where people are coming from and what matters to them
# [Human 2] Yea, me too. I feel like God often puts strangers in front of you, and gives you an opportunity to connect with them in that moment in deeply meaningful ways. Do you ever feel like you know things about strangers without them telling you?
# [Human 1] what do you mean?
# [Human 2] I think it's like a 6th sense, often seen as "cold readings" to people, but can be remarkably accurate. I once sat next to a man in a coffee and I felt a pain in my back. I asked the stranger if he had a pain. It turns out that he did in the exact spot, and said he pulled a muscle while dancing at a party. I had never met the man before and never saw him again.
# [Human 1] Wow! That's interesting, borderline spooky
# [Human 2] There's this practice called "Treasure Hunting" that's kind of a fun game you play in a public place. There's a book called "The Ultimate Treasure Hunt" that talks about it. You use your creativity to imagine people you will meet, and you write down a description, then you associate them with a positive message or encouraging word. Maybe you saw a teenage boy in a red hat at the shopping mall in your imagination, then while at the mall, you may find someone who matches that description. You show that you have a message for him and that you have a message for a boy in a red hat. You then give him a message of kindness or whatever was on your heart. You have no idea, sometimes you meet someone who is having a really hard day, and it brings them to tears to have a stranger show them love.
# [Human 1] So, do you do treasure hunting often?

# %% [markdown]
# ## Training the Transformer

# %%
# get the data file
file_path = "/content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/human_chat_new_processed_gpt2.txt"

# initialize parameters for the GPT-2-simple
learning_rate= 0.0001
save_path= "/content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/data/models_trained"
model_size= "124M"
steps= 600
restore_from= "fresh"
print_every= 1
sample_every= 300
save_every= 300

# %%
timestamp = datetime.utcnow().strftime('%Y%m%d%H%M%S')
model_dir = save_path
model_name = model_size
run_name = f"gp2simple_new_{model_size}_{timestamp}"
gpt2.download_gpt2(model_name=model_name, model_dir=model_dir)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 94.3Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 5.81Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 489Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:10, 48.8Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 542Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 9.57Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 9.65Mit/s]

# %%
# Fine-Tuning the model

# Commenting the code for training since already fine-tuned and saved the model weights
"""
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              model_dir=model_dir,
              model_name=model_name,
              checkpoint_dir=model_dir,
              run_name=run_name,
              dataset=file_path,
              steps=steps,
              learning_rate=learning_rate,
              restore_from=restore_from,
              print_every=print_every,
              sample_every=sample_every,
              save_every=save_every)
"""
# Out:
# Loading checkpoint ./data/models_trained/124M\model.ckpt
# INFO:tensorflow:Restoring parameters from ./data/models_trained/124M\model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# dataset has 32560 tokens
# Training...
# [1 | 46.45] loss=2.73 avg=2.73
# [2 | 84.30] loss=2.79 avg=2.76
# [3 | 122.23] loss=2.61 avg=2.71
# [4 | 158.99] loss=2.47 avg=2.65
# [5 | 198.33] loss=2.59 avg=2.64
# [6 | 237.67] loss=2.45 avg=2.60
# [7 | 273.43] loss=2.50 avg=2.59
# [8 | 309.22] loss=2.37 avg=2.56
# [9 | 345.35] loss=2.50 avg=2.55
# [10 | 382.43] loss=2.22 avg=2.52
# [11 | 417.51] loss=2.45 avg=2.51
# [12 | 453.66] loss=2.27 avg=2.49
# [13 | 487.90] loss=2.26 avg=2.47
# [14 | 521.64] loss=2.25 avg=2.45
# [15 | 559.90] loss=2.27 avg=2.44
# [16 | 599.65] loss=2.20 avg=2.42
# [17 | 640.53] loss=2.22 avg=2.41
# [18 | 678.83] loss=2.21 avg=2.40
# [19 | 722.59] loss=2.13 avg=2.38
# [20 | 762.31] loss=2.08 avg=2.37
# [21 | 801.19] loss=2.20 avg=2.36
# [22 | 840.38] loss=1.99 avg=2.34
# [23 | 876.70] loss=1.96 avg=2.32
# [24 | 911.85] loss=2.21 avg=2.32
# [25 | 946.89] loss=1.80 avg=2.29
# [26 | 990.79] loss=1.91 avg=2.28
# [27 | 1038.34] loss=1.93 avg=2.26
# [28 | 1081.87] loss=1.88 avg=2.25
# [29 | 1122.62] loss=1.80 avg=2.23
# [30 | 1161.75] loss=1.65 avg=2.21
# [31 | 1200.73] loss=1.91 avg=2.20
# [32 | 1240.44] loss=1.74 avg=2.18
# [33 | 1280.34] loss=1.54 avg=2.16
# [34 | 1324.84] loss=1.53 avg=2.13
# [35 | 1376.39] loss=1.84 avg=2.12
# [36 | 1420.55] loss=1.75 avg=2.11
# [37 | 1472.07] loss=1.69 avg=2.10
# [38 | 1517.57] loss=1.68 avg=2.09
# [39 | 1559.31] loss=1.73 avg=2.07
# [40 | 1600.88] loss=1.43 avg=2.05
# [41 | 1641.80] loss=1.59 avg=2.04
# [42 | 1680.39] loss=1.57 avg=2.03
# [43 | 1722.62] loss=1.38 avg=2.01
# [44 | 1768.14] loss=1.40 avg=1.99
# [45 | 1814.16] loss=1.18 avg=1.97
# [46 | 1858.71] loss=1.19 avg=1.95
# [47 | 1898.09] loss=1.31 avg=1.93
# [48 | 1937.43] loss=1.48 avg=1.92
# [49 | 1973.63] loss=1.28 avg=1.90
# [50 | 2009.99] loss=1.05 avg=1.88
# [51 | 2046.24] loss=1.42 avg=1.87
# [52 | 2082.75] loss=1.22 avg=1.85
# [53 | 2121.42] loss=1.03 avg=1.83
# [54 | 2169.72] loss=1.20 avg=1.82
# [55 | 2229.64] loss=1.08 avg=1.80
# [56 | 2281.46] loss=1.01 avg=1.78
# [57 | 2323.57] loss=1.01 avg=1.77
# [58 | 2370.90] loss=0.87 avg=1.75
# [59 | 2418.38] loss=0.95 avg=1.73
# [60 | 2461.79] loss=0.98 avg=1.71
# [61 | 2498.54] loss=0.75 avg=1.69
# [62 | 2537.85] loss=1.09 avg=1.68
# [63 | 2594.85] loss=1.07 avg=1.66
# [64 | 2639.22] loss=1.06 avg=1.65
# [65 | 2678.66] loss=0.82 avg=1.63
# [66 | 2713.67] loss=0.79 avg=1.62
# [67 | 2748.37] loss=0.69 avg=1.60
# [68 | 2782.42] loss=0.85 avg=1.58
# [69 | 2816.20] loss=0.64 avg=1.56
# [70 | 2850.07] loss=0.64 avg=1.55
# [71 | 2883.95] loss=0.60 avg=1.53
# [72 | 2918.23] loss=0.58 avg=1.51
# [73 | 2952.02] loss=0.57 avg=1.49
# [74 | 2987.41] loss=0.39 avg=1.47
# [75 | 3023.27] loss=0.76 avg=1.46
# [76 | 3070.63] loss=0.46 avg=1.44
# [77 | 3111.60] loss=0.56 avg=1.42
# [78 | 3147.50] loss=0.75 avg=1.41
# [79 | 3182.00] loss=0.45 avg=1.39
# [80 | 3216.40] loss=0.55 avg=1.38
# [81 | 3250.45] loss=0.38 avg=1.36
# [82 | 3284.17] loss=0.54 avg=1.34
# [83 | 3317.50] loss=0.32 avg=1.33
# [84 | 3351.02] loss=0.36 avg=1.31
# [85 | 3384.45] loss=0.32 avg=1.29
# [86 | 3418.16] loss=0.35 avg=1.28
# [87 | 3451.97] loss=0.31 avg=1.26
# [88 | 3485.41] loss=0.39 avg=1.24
# [89 | 3519.89] loss=0.26 avg=1.23
# [90 | 3554.10] loss=0.23 avg=1.21
# [91 | 3587.98] loss=0.42 avg=1.20
# [92 | 3621.86] loss=0.30 avg=1.18
# [93 | 3655.66] loss=0.21 avg=1.17
# [94 | 3689.66] loss=0.29 avg=1.15
# [95 | 3723.86] loss=0.38 avg=1.14
# [96 | 3758.02] loss=0.21 avg=1.12
# [97 | 3792.24] loss=0.56 avg=1.12
# [98 | 3827.51] loss=0.22 avg=1.10
# [99 | 3861.24] loss=0.18 avg=1.09
# [100 | 3904.63] loss=0.20 avg=1.07
# [101 | 3940.47] loss=0.18 avg=1.06
# [102 | 3975.39] loss=0.20 avg=1.05
# [103 | 4009.15] loss=0.16 avg=1.03
# [104 | 4043.02] loss=0.16 avg=1.02
# [105 | 4076.06] loss=0.19 avg=1.01
# [106 | 4109.42] loss=0.11 avg=0.99
# [107 | 4143.08] loss=0.12 avg=0.98
# [108 | 4176.49] loss=0.18 avg=0.97
# [109 | 4210.08] loss=0.19 avg=0.95
# [110 | 4243.38] loss=0.13 avg=0.94
# [111 | 4276.70] loss=0.14 avg=0.93
# [112 | 4314.97] loss=0.15 avg=0.92
# [113 | 4356.56] loss=0.12 avg=0.91
# [114 | 4398.27] loss=0.19 avg=0.90
# [115 | 4437.69] loss=0.14 avg=0.89
# [116 | 4476.90] loss=0.11 avg=0.87
# [117 | 4511.59] loss=0.16 avg=0.86
# [118 | 4546.05] loss=0.13 avg=0.85
# [119 | 4579.57] loss=0.17 avg=0.84
# [120 | 4612.92] loss=0.12 avg=0.83
# [121 | 4646.39] loss=0.08 avg=0.82
# [122 | 4680.22] loss=0.12 avg=0.81
# [123 | 4713.66] loss=0.07 avg=0.80
# [124 | 4747.22] loss=0.09 avg=0.79
# [125 | 4781.15] loss=0.09 avg=0.78
# [126 | 4814.16] loss=0.07 avg=0.77
# [127 | 4847.12] loss=0.06 avg=0.76
# [128 | 4880.19] loss=0.07 avg=0.75
# [129 | 4913.68] loss=0.11 avg=0.74
# [130 | 4947.39] loss=0.08 avg=0.74
# [131 | 4981.15] loss=0.09 avg=0.73
# [132 | 5014.30] loss=0.07 avg=0.72
# [133 | 5047.11] loss=0.06 avg=0.71
# [134 | 5079.62] loss=0.08 avg=0.70
# [135 | 5112.27] loss=0.07 avg=0.69
# [136 | 5145.20] loss=0.08 avg=0.68
# [137 | 5178.80] loss=0.06 avg=0.68
# [138 | 5212.44] loss=0.08 avg=0.67
# [139 | 5246.19] loss=0.08 avg=0.66
# [140 | 5279.62] loss=0.07 avg=0.65
# [141 | 5313.38] loss=0.06 avg=0.64
# [142 | 5347.08] loss=0.08 avg=0.64
# [143 | 5380.84] loss=0.09 avg=0.63
# [144 | 5414.18] loss=0.06 avg=0.62
# [145 | 5447.87] loss=0.07 avg=0.61
# [146 | 5481.45] loss=0.06 avg=0.61
# [147 | 5515.67] loss=0.07 avg=0.60
# [148 | 5550.46] loss=0.05 avg=0.59
# [149 | 5585.33] loss=0.07 avg=0.59
# [150 | 5620.48] loss=0.06 avg=0.58
# [151 | 5655.38] loss=0.06 avg=0.57
# [152 | 5689.54] loss=0.05 avg=0.57
# [153 | 5723.08] loss=0.09 avg=0.56
# [154 | 5756.63] loss=0.06 avg=0.55
# [155 | 5790.27] loss=0.07 avg=0.55
# [156 | 5823.80] loss=0.06 avg=0.54
# [157 | 5857.40] loss=0.06 avg=0.54
# [158 | 5890.78] loss=0.06 avg=0.53
# [159 | 5924.35] loss=0.04 avg=0.52
# [160 | 5957.71] loss=0.04 avg=0.52
# [161 | 5991.18] loss=0.22 avg=0.51
# [162 | 6024.44] loss=0.05 avg=0.51
# [163 | 6057.84] loss=0.06 avg=0.50
# [164 | 6091.43] loss=0.06 avg=0.50
# [165 | 6125.39] loss=0.06 avg=0.49
# [166 | 6159.34] loss=0.06 avg=0.49
# [167 | 6193.23] loss=0.06 avg=0.48
# [168 | 6226.93] loss=0.05 avg=0.48
# [169 | 6260.36] loss=0.05 avg=0.47
# [170 | 6293.89] loss=0.08 avg=0.47
# [171 | 6327.46] loss=0.06 avg=0.46
# [172 | 6361.12] loss=0.06 avg=0.46
# [173 | 6394.65] loss=0.06 avg=0.45
# [174 | 6428.14] loss=0.06 avg=0.45
# [175 | 6461.57] loss=0.04 avg=0.44
# [176 | 6495.15] loss=0.05 avg=0.44
# [177 | 6528.81] loss=0.06 avg=0.43
# [178 | 6562.59] loss=0.06 avg=0.43
# [179 | 6597.81] loss=0.04 avg=0.42
# [180 | 6631.28] loss=0.05 avg=0.42
# [181 | 6664.77] loss=0.06 avg=0.41
# [182 | 6698.34] loss=0.05 avg=0.41
# [183 | 6732.51] loss=0.04 avg=0.41
# [184 | 6766.18] loss=0.05 avg=0.40
# [185 | 6799.97] loss=0.05 avg=0.40
# [186 | 6833.34] loss=0.05 avg=0.39
# [187 | 6867.27] loss=0.04 avg=0.39
# [188 | 6900.76] loss=0.05 avg=0.39
# [189 | 6934.20] loss=0.11 avg=0.38
# [190 | 6967.73] loss=0.05 avg=0.38
# [191 | 7001.26] loss=0.06 avg=0.37
# [192 | 7034.91] loss=0.04 avg=0.37
# [193 | 7068.51] loss=0.05 avg=0.37
# [194 | 7102.02] loss=0.05 avg=0.36
# [195 | 7135.48] loss=0.04 avg=0.36
# [196 | 7168.98] loss=0.04 avg=0.36
# [197 | 7202.41] loss=0.05 avg=0.35
# [198 | 7236.01] loss=0.06 avg=0.35
# [199 | 7269.53] loss=0.05 avg=0.34
# [200 | 7303.30] loss=0.07 avg=0.34
# [201 | 7337.29] loss=0.05 avg=0.34
# [202 | 7371.24] loss=0.04 avg=0.33
# [203 | 7405.13] loss=0.06 avg=0.33
# [204 | 7438.60] loss=0.04 avg=0.33
# [205 | 7472.15] loss=0.04 avg=0.33
# [206 | 7505.64] loss=0.04 avg=0.32
# [207 | 7539.29] loss=0.03 avg=0.32
# [208 | 7572.93] loss=0.05 avg=0.32
# [209 | 7606.45] loss=0.04 avg=0.31
# [210 | 7640.37] loss=0.04 avg=0.31
# [211 | 7673.91] loss=0.06 avg=0.31
# [212 | 7707.46] loss=0.05 avg=0.30
# [213 | 7740.86] loss=0.04 avg=0.30
# [214 | 7774.70] loss=0.05 avg=0.30
# [215 | 7808.20] loss=0.05 avg=0.29
# [216 | 7841.78] loss=0.06 avg=0.29
# [217 | 7875.17] loss=0.04 avg=0.29
# [218 | 7910.58] loss=0.05 avg=0.29
# [219 | 7945.54] loss=0.05 avg=0.28
# [220 | 7979.66] loss=0.05 avg=0.28
# [221 | 8013.57] loss=0.05 avg=0.28
# [222 | 8047.22] loss=0.04 avg=0.28
# [223 | 8081.04] loss=0.04 avg=0.27
# [224 | 8114.67] loss=0.04 avg=0.27
# [225 | 8148.48] loss=0.04 avg=0.27
# [226 | 8182.11] loss=0.04 avg=0.27
# [227 | 8215.86] loss=0.04 avg=0.26
# [228 | 8248.36] loss=0.04 avg=0.26
# [229 | 8280.61] loss=0.05 avg=0.26
# [230 | 8312.61] loss=0.04 avg=0.26
# [231 | 8345.20] loss=0.03 avg=0.25
# [232 | 8377.52] loss=0.06 avg=0.25
# [233 | 8409.76] loss=0.05 avg=0.25
# [234 | 8442.57] loss=0.04 avg=0.25
# [235 | 8474.88] loss=0.04 avg=0.24
# [236 | 8507.39] loss=0.04 avg=0.24
# [237 | 8540.22] loss=0.03 avg=0.24
# [238 | 8572.84] loss=0.05 avg=0.24
# [239 | 8605.20] loss=0.03 avg=0.24
# [240 | 8637.27] loss=0.04 avg=0.23
# [241 | 8669.45] loss=0.05 avg=0.23
# [242 | 8702.04] loss=0.03 avg=0.23
# [243 | 8734.17] loss=0.05 avg=0.23
# [244 | 8766.17] loss=0.04 avg=0.23
# [245 | 8798.25] loss=0.04 avg=0.22
# [246 | 8830.63] loss=0.04 avg=0.22
# [247 | 8862.63] loss=0.04 avg=0.22
# [248 | 8894.72] loss=0.05 avg=0.22
# [249 | 8926.96] loss=0.03 avg=0.22
# [250 | 8959.07] loss=0.03 avg=0.21
# [251 | 8991.23] loss=0.05 avg=0.21
# [252 | 9025.29] loss=0.03 avg=0.21
# [253 | 9057.69] loss=0.04 avg=0.21
# [254 | 9090.47] loss=0.03 avg=0.21
# [255 | 9123.33] loss=0.03 avg=0.20
# [256 | 9156.49] loss=0.04 avg=0.20
# [257 | 9189.13] loss=0.04 avg=0.20
# [258 | 9221.83] loss=0.03 avg=0.20
# [259 | 9254.74] loss=0.04 avg=0.20
# [260 | 9287.45] loss=0.04 avg=0.20
# [261 | 9320.62] loss=0.04 avg=0.19
# [262 | 9354.18] loss=0.05 avg=0.19
# [263 | 9387.89] loss=0.04 avg=0.19
# [264 | 9421.13] loss=0.06 avg=0.19
# [265 | 9453.85] loss=0.03 avg=0.19
# [266 | 9485.95] loss=0.05 avg=0.19
# [267 | 9517.90] loss=0.04 avg=0.18
# [268 | 9550.35] loss=0.04 avg=0.18
# [269 | 9582.41] loss=0.03 avg=0.18
# [270 | 9614.87] loss=0.04 avg=0.18
# [271 | 9646.74] loss=0.04 avg=0.18
# [272 | 9678.74] loss=0.04 avg=0.18
# [273 | 9711.19] loss=0.03 avg=0.18
# [274 | 9743.52] loss=0.04 avg=0.17
# [275 | 9776.07] loss=0.04 avg=0.17
# [276 | 9808.32] loss=0.03 avg=0.17
# [277 | 9840.56] loss=0.03 avg=0.17
# [278 | 9872.70] loss=0.04 avg=0.17
# [279 | 9904.77] loss=0.04 avg=0.17
# [280 | 9936.84] loss=0.04 avg=0.17
# [281 | 9968.98] loss=0.03 avg=0.16
# [282 | 10001.16] loss=0.03 avg=0.16
# [283 | 10033.11] loss=0.03 avg=0.16
# [284 | 10065.21] loss=0.04 avg=0.16
# [285 | 10098.49] loss=0.04 avg=0.16
# [286 | 10136.05] loss=0.04 avg=0.16
# [287 | 10186.31] loss=0.04 avg=0.16
# [288 | 10227.57] loss=0.04 avg=0.15
# [289 | 10268.05] loss=0.04 avg=0.15
# [290 | 10307.47] loss=0.03 avg=0.15
# [291 | 10347.02] loss=0.04 avg=0.15
# [292 | 10384.56] loss=0.03 avg=0.15
# [293 | 10421.48] loss=0.04 avg=0.15
# [294 | 10464.05] loss=0.05 avg=0.15
# [295 | 10504.15] loss=0.05 avg=0.15
# [296 | 10543.55] loss=0.04 avg=0.15
# [297 | 10584.33] loss=0.04 avg=0.14
# [298 | 10623.98] loss=0.04 avg=0.14
# [299 | 10662.07] loss=0.04 avg=0.14
# [300 | 10698.58] loss=0.03 avg=0.14
# Saving ./data/models_trained/02_gp2simple_124M_20221120002951\model-300
# ======== SAMPLE 1 ========
#  I can work as a poodle
# [Human 2] That's a good way of framing it. I'm in a bit of a dilemma. Do I come up with a clever solution or do I stay home and work?
# [Human 1] I think I'm in the latter phase of puberty. I sometimes drift off during puberty, so I won't count them in your mind. I do know there's a medication available for side effects withv all of this speculation.
# [Human 2] I heard about tDCS before. It's a high-powered, high-tension, high-pulse, high-disruptive, very high-pulse kind of technology. It's not intended for everyday use, but could potentially be very useful in diagnosing health problems later on.
# [Human 1] EE I'm Peter Thiel. I'm cofounder oftoshi. I'm a board member ofventurecapital.com and member of theJobs World Just released a report today called "The 21st Century in Adtech." It's a fascinating time to be a Silicon Valley billionaire."
# [Human 2] The world is literally changing! How about you?
# [Human 1] I think I'm in the 21st century. I inventing ways to survive in the 21st, or whatever you want to call it, is simply terrible.
# [Human 2] hahahaha, that is a good place to start.
# [Human 1] The 21st is the most important milestone in human history. Today, we are at the turning point. I believe this country can and should live up to as they have done for many, many years.
# [Human 2] The past five presidents have been born during that time span. The other Republican has been a world leader.
# [Human 1] Both of us, what do you think makes this election more important to you?
# [Human 2] People are giving me these questions. Why are you doing these public records requests?
# [Human 1] Because I have the power to destroy the GOP.
# [Human 2] That's a much harder task, doesn't it?
# [Human 1] Hi
# [Human 2] Hello, how are you doing today?
# [Human 1] I heard they are giving out some goodies in microkitchen.
# [Human 2] That's great. How's the food?
# [Human 1] I heard there are meals for lunch and dinner on sale for just under $1,000. I will chime in as soon as they get my order.
# [Human 2] That's good. I'll pick up something unhealthy and some good food. Do you have any good ramen?
# [Human 1] Ioners are a favorite, but I haven't tried ramen in a while. Not to brag but ramen is a pain in the arse and I'm not a moron - I know plenty of people who go to pet heaven.
# [Human 2] That's true. Though I admit, I'm a bit sad that I cannot get by trash can. Me personally, I don't like it when things bad happen to nice people.
# [Human 1] Are you a food person, a sight to see?
# [Human 2] Yes! I think of all the food I have eaten that had been turned into food before they are packaged and gone bad.
# [Human 1] Have you ever had bad ramen?
# [Human 2] I have never had bad ramen, but my bad experience with it is pretty bad. I have tried ramen hot dogs and pikachu. I will definitely try his.
# [Human 1] Great! Have you tried any of his other ramen options?
# [Human 2] He has never had pikachu, but pikachu is still bothering me. Got any good ramen snub?
# [Human 1] Hee hee hee! here it is :slightly_smiling_face: Phew! I love hot dogs or pikachu.
# [Human 2] Hot dogs and tennis? Yep, we had a lot of fun last week. We booked a room at a friends place and we snubbed pikachu. I think the pikachu that we snuck into the bar were too lazy to finish up before us.
# [Human 1] We SWEAT! Did we not say lazy? Did we not say anything about our meal?
# [Human 2] We SWEAT! Did we not say anything lazy? If we did, we probably would not be able to nap this much. We had a pretty good chance of getting snoozed.
# [Human 1] We slept well we>>>>>>>> thought but woke up too late
# [Human 2] We could have snoozed earlier had we known about the lagus ting
# [Human 1] We did not, and woke up too late
# [Human 2
#
# [301 | 10842.45] loss=0.04 avg=0.14
# [302 | 10879.30] loss=0.03 avg=0.14
# [303 | 10918.01] loss=0.03 avg=0.14
# [304 | 10954.47] loss=0.05 avg=0.14
# interrupted
# Saving ./data/models_trained/02_gp2simple_124M_20221120002951\model-304
# WARNING:tensorflow:From C:\Users\sjain\anaconda3\envs\HW2\lib\site-packages\tensorflow\python\training\saver.py:1064: remove_checkpoint (from tensorflow.python.checkpoint.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.

# %%
# retrieve saved previosuly custom fine-tuned model
checkpoint_dir="/content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/data/models_trained/02_gp2simple_new124_124M_20221124005804"
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, checkpoint_dir=checkpoint_dir)
# Out:
# Loading checkpoint /content/drive/MyDrive/Colab Notebooks/CSCI 544: ANLP/NLP_Group_Project/GPT_3_Model/data/models_trained/02_gp2simple_new124_124M_20221124005804/run1/model-600

# %%
# Initialize Sentiment Analyzer
import nltk

nltk.download([
     "stopwords",
     "averaged_perceptron_tagger",
     "vader_lexicon",
     "punkt"
])

from nltk.sentiment import SentimentIntensityAnalyzer
sentimentAnalyzer = SentimentIntensityAnalyzer()
possibleSentiments = ['pos', 'neu', 'neg']
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Initialize Generic / Discrete Model
from transformers import BlenderbotTokenizer, BlenderbotForConditionalGeneration

mname = "facebook/blenderbot-400M-distill"
discreteModel = BlenderbotForConditionalGeneration.from_pretrained(mname)
tokenizer = BlenderbotTokenizer.from_pretrained(mname)
# Out:
# Downloading:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/730M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/127k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/62.9k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/16.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %%
# # Generate response
# question = input()
# # print()

# prefix = '[Human 2] '+ question + '\n[Human 1]'
# temperature = 0.90

# # check the sentiment of input prompt
# sentimentScores = sentimentAnalyzer.polarity_scores(question)

# # Printing sentiment scores
# print('\nSentiment Scores -')
# for sentiment in possibleSentiments:
#   print('{}: {}'.format(sentiment, sentimentScores[sentiment]))


# # Get the highest score/probability sentiment
# quesSentiment = None
# maxVal = -1
# for sentiment in possibleSentiments:
#   if sentimentScores[sentiment] > maxVal:
#     maxVal = sentimentScores[sentiment]
#     quesSentiment = sentiment


# # check if we call fine-tuned transformer for response, or the discrete/generic model
# if quesSentiment in ['pos', 'neu']:
#   # Use the fine-tuned model if sentiment is positive or neutral
#   print('\nCalling Fine-Tuned Transformer for response -')
#   text_generated = gpt2.generate(
#       sess,
#       checkpoint_dir=checkpoint_dir,
#       length=80,
#       temperature=temperature,
#       prefix=prefix,
#       return_as_list=True
#   )
#   # print(text_generated[0])

#   response = text_generated[0].split(sep='\n')
#   response = response[:2]

#   for i, row in enumerate(response):
#       # print(row)
#       person, sentence = row.split(sep=']', maxsplit=1)
#       person = person[1:]
#       sentence = sentence.strip()
#       if person == 'Human 2':
#           person = '\nQuestion: '
#       else:
#           person = 'Response: '
#       response[i] = person + sentence

#   for row in response:
#       print(row)

# # Use Generic/Discrete Model otherwise in case of hateful prompt
# else:
#   print('\n\nCalling Generic/Discrete Model for response -')

#   inputs = tokenizer([question], return_tensors="pt")
#   reply_ids = discreteModel.generate(**inputs)
#   response = tokenizer.batch_decode(reply_ids)
#   response = response[0]
#   response = response.split('>')[1].split('<')[0]
#   print('\nQuestion: ', question)
#   print('Response: ', response)
# Out:
# Do you have a cat?
#
# Sentiment Scores -
# pos: 0.0
# neu: 1.0
# neg: 0.0
#
# Calling Fine-Tuned Transformer for response -
#
# Question: Do you have a cat?
# Response: He's so cute I am imagining him playing soccer on his phone right now. I want to play it with him for a while, and then I'll get to play it with him actually. Are you planning anything for the holidays?

# %%
# Generate response
question = input()
# print()

prefix = '[Human 2] '+ question + '\n[Human 1]'
temperature = 0.90
res = ''

# check the sentiment of input prompt
sentimentScores = sentimentAnalyzer.polarity_scores(question)

# Printing sentiment scores
res += 'Sentiment Scores -'
for sentiment in possibleSentiments:
  res += '\n{}: {}'.format(sentiment, sentimentScores[sentiment])



# Get the highest score/probability sentiment
quesSentiment = None
maxVal = -1
for sentiment in possibleSentiments:
  if sentimentScores[sentiment] > maxVal:
    maxVal = sentimentScores[sentiment]
    quesSentiment = sentiment



# check if we call fine-tuned transformer for response, or the discrete/generic model
if quesSentiment in ['pos', 'neu']:
  # Use the fine-tuned model if sentiment is positive or neutral
  res += '\n\nCalling Fine-Tuned Transformer for response -'
  text_generated = gpt2.generate(
      sess,
      checkpoint_dir=checkpoint_dir,
      length=80,
      temperature=temperature,
      prefix=prefix,
      return_as_list=True
  )
  # print(text_generated[0])

  response = text_generated[0].split(sep='\n')
  response = response[:2]

  for i, row in enumerate(response):
      # print(row)
      person, sentence = row.split(sep=']', maxsplit=1)
      person = person[1:]
      sentence = sentence.strip()
      if person == 'Human 2':
          person = '\n\nQuestion: '
      else:
          person = '\nResponse: '
      response[i] = person + sentence

  for row in response:
      res += row

# Use Generic/Discrete Model otherwise in case of hateful prompt
else:
  res += '\n\nCalling Generic/Discrete Model for response -'

  inputs = tokenizer([question], return_tensors="pt")
  reply_ids = discreteModel.generate(**inputs)
  response = tokenizer.batch_decode(reply_ids)
  response = response[0]
  response = response.split('>')[1].split('<')[0]
  res += '\n\nQuestion: ' + question
  res += '\nResponse: ' + response
# Out:
# Want to travel to Europe?

# %%
print(res)
# Out:
# Sentiment Scores -
# pos: 0.245
# neu: 0.755
# neg: 0.0
#
# Calling Fine-Tuned Transformer for response -
#
# Question: Want to travel to Europe?
# Response: Yes! I want to one day go into space!
